# %% [markdown]
# **IU000128 Coding3: Exploring Machine Intelligence Part 1**
#
# For more info, please check [Coding3 part 2](https://colab.research.google.com/drive/1l3z4I9KehQgtLqnOCSWH3m6II_xshuiF#scrollTo=PiyjEOM1XoL7)
#
# ---
#
#
# ## GPT-2 (small) and Text Generation - by YIFAN FENG
#
#
# #### Main Reference
#
#
# *   [GPT-2 Fine Tune](https://colab.research.google.com/gist/MattPitlyk/45541145ad48b93da395f0a72ec2e7dc/fine-tuning-gpt-2-on-a-custom-dataset.ipynb)
#
# *   [GPT-2 Custom Dataset](https://medium.com/ai-innovation/beginners-guide-to-retrain-gpt-2-117m-to-generate-custom-text-content-8bb5363d8b7f)
#
# *   [Training Dataset: Oxford Handbook of Ethics of AI](https://www.oxfordhandbooks.com/view/10.1093/oxfordhb/9780190067397.001.0001/oxfordhb-9780190067397)

# %% [markdown]
# ### Import Libs and Set up Env

# %%
from google.colab import drive #Access GoogleDrive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#set-up 
import nltk, re, string
from string import punctuation 
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords_list = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Basic Text Cleaning
# #### Reference
# *   [IU000131: NLP for the Creative Industries Week 1.2](https://git.arts.ac.uk/lmccallum/nlp-21-22/blob/master/NLP%20Week%201.2-Solutions.ipynb)
# *[Clean and Tokenize Text With Python](https://dylancastillo.co/nlp-snippets-clean-and-tokenize-text-with-python/)

# %%
#Use the following three functions to cleanse dataset
#Exclude excessive whitespace 

def remove_whitespace(textfile):
  return "\n".join(re.findall(r"^\s*\b(.*?)\s*$", textfile, flags=re.MULTILINE))

#Exclude excessive paragraphs 
def remove_newlines(textfile):
  return re.sub(r'[\r\n]{3}',"", textfile) 

#Exclude punctuation
def remove_punctuation(textfile):
  return re.sub(f"[{re.escape(punctuation)}]", "", textfile)

#Exlcude stopwords
def remove_stopwords (textfile):
  wordtokens = textfile.split()
  clean_wordtokens = [word for word in wordtokens if not word in stopwords_list]
  clean_text = " ".join(clean_wordtokens)
  return clean_text 

#Exlude numbers 
def remove_numbers(textfile):
  return re.sub(r"\b[0-9]+\b\s*", "", textfile)

#Exlude digits 
def remove_digits(textfile):
  new_text = " ".join([w for w in textfile.split() if not w.isdigit()])
  return new_text

def processText(text):
  rm_whitespace = remove_whitespace(text)
  rm_newlines = remove_newlines(rm_whitespace)
  rm_punctuation = remove_punctuation (rm_newlines)
  rm_numbers = remove_numbers(rm_punctuation)
  rm_digits = remove_digits(rm_numbers)
  rm_stoppers = remove_stopwords(rm_digits)
  return rm_stoppers

# %%
#Read text file 
textfile_path = '/content/drive/MyDrive/Coding3/oxford_ai.txt'
file = open(textfile_path, 'rt')
text = file.read().lower()
file.close() 

#Process text file for a new document
rm_stoppers = processText(text)

# %%
updated_textfile = rm_stoppers #reassign a variable name to the string

# %%
#Write the file
newfile_path = '/content/drive/MyDrive/Coding3/oxford_ai_cleaned.txt'
new_file = open(newfile_path,'w')
new_file.write(updated_textfile)
new_file.close()

# %% [markdown]
# ### GPT-2 Fine-Tuning
#
# *Reference see above*
#
#
# *   [Understanding GPT-2 source code 1](https://medium.com/analytics-vidhya/understanding-the-gpt-2-source-code-part-1-4481328ee10b)
# *   [Understanding GPT-2 source code 2](https://medium.com/analytics-vidhya/understanding-the-gpt-2-source-code-part-2-4a980c36c68b)

# %%
# !pip install -q gpt-2-simple
# %tensorflow_version 1.x
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
import tensorflow as tf
# Out:
#   Building wheel for gpt-2-simple (setup.py) ... done
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name="355M") #other options: 124M
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 491Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 2.86Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 284Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:48, 29.5Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 282Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 2.88Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.69Mit/s]

# %%
'''
#for file store in google drive
gpt2.mount_gdrive()
gpt2.copy_file_from_gdrive(file_name)
'''
file_name = "/content/drive/MyDrive/Coding3/oxford_ai_cleaned.txt"
checkpoint_name = "/content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1" 
model_size = '355M'
checkpoint_file = '/content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1/model-1000.data-00000-of-00001'

tf.reset_default_graph() #re-finetune if training fails 
sess = gpt2.start_tf_sess() 
gpt2.finetune(sess,
              dataset=file_name,
              model_name= model_size, #Small options: 124M
              model_dir='models', 
              steps=1000, #training iteration, total ~8.5k 
              restore_from= 'latest', #other options: fresh or checkpoint_file
              run_name = checkpoint_name, 
              save_every= 400, #write a checkpoint every N steps
              use_memory_saving_gradients = True,
              only_train_transformer_layers = False,
              accumulate_gradients = 1,
              learning_rate=0.0001, 
              sample_every=100) #generate samples every N steps

#Save checkpoint to Google Drive 
gpt2.copy_checkpoint_to_gdrive(checkpoint_name)
# Out:
# For larger models, the recommended finetune() parameters are:
# 	use_memory_saving_gradients = True
# 	only_train_transformer_layers = True
# 	accumulate_gradients = 1
#
# Loading checkpoint /content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1/model-5000
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1/model-5000
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.33s/it]
# dataset has 326722 tokens
# Training...
# ======== SAMPLE 1 ========
# �joshua kroll et al eth r evans “regulating scheduling autonomous intelligent systems” science joshua kroll et al “regulating scheduling autonomous intelligent systems human role scheduling practices” lancet joshcia calders karen ec levy greg hager “assessing risk assessment action” minnesota law review –depaulo bel deborah kashy susan leigh starck “bias computer systems” acm joshua kroll et al “algorithmic decisionmaking based machine learning” figure slight unorthodoxy may result positive attributes—inability human oversight oversight oversight—but also potential risks outlined following discussion two aspects kashy susan leigh starck’s book society algorithms1Initialized many discussions algorithmic bias theory ai2 become involved controversies particular researchers project building neural networks causal ancestors tomahawks phase issues causal dependence neu evolution epistemology ethics ai depend data tradition goes way back natural social creatures creatures live world today’s ai follow philosophy provide us Millennial citation beltway neil maccormick notes “as least since maccormick’s day people inclined say apple don’t owe duty pay taxes bess leigh starck fact arbitrary power decision makers anything even frontiers free speech ideas free press question knowable knows become involved scandals others speak us liking—or hearing us’s telling tale outrage word spread like mad dogs96 effects may far subtle original formulation maccormick’s infamous trolley problem may accurate current technology exists try reduce impact external cognitive artifacts—at least now9 many discussions ai foresee world programmed highfidelity sensory effi ciently accurate pure speculation type requires intelligence vast computational resources even powers intelli gently designed small brains mere beings manipulate information exchange environment solely human cognitive ability would entirely different programmed thing understand avoid want follow spirit believe us robot know cannot understand also cannot understand that us whatever intelligence remaining hand maccormick’s trolley problem clearly conceptualized mechanism pushing pull pull pull came first place—in dire need need ever need ever revisit concept carpendham london nussbaum g bellemare eds artificial intel igence foundations theory judgment oxford oxford university press khalil gibran muhammad condemnation blackness oxford oxford university press meg leta jones elizabeth edenberg concepts issues chapter we’ve created artificial intelligence capable making use vast amounts data available digital world yet intelligence pure technical definition comes much debate artificial intelligence despite often prevailing academic wisdom traditional definitions explain lack “mere” intelligence preferring instead develop nuanced notion based shared neural processing systems31 ai systems use data generate knowledge course work algorithmic knowledge discovery process build predictive models associations data sets systems able create sist anse correlations associations meant understand associations patterns data points32 explain association cranial data points shared set associated probability paretian probabilities shared set associated associated causal explanation intelligence far less amenable modern computational methods one recent example news world university stops allow computers debate debate debated whether “il ustrateslave” declaration last decade lead us creation artificial intelligence question since answered artificial intelligence defined brain brain though distinct neural processing systems yes brain certainly influences one act another though obviously act first place given status humankind standard definition explained alphagovernment agency iaa “artificial intelligence” refers computational systems able simulate human cognition using ai lead us overestimate human intelligence status computers even could create infinitely effective machines course would definitional difficult machine def ...
#
# [5001 | 31.27] loss=0.25 avg=0.25
# [5002 | 32.19] loss=0.08 avg=0.16
# [5003 | 33.09] loss=0.20 avg=0.18
# [5004 | 33.99] loss=0.12 avg=0.16
# [5005 | 34.90] loss=0.07 avg=0.14
# [5006 | 35.80] loss=0.10 avg=0.13
# [5007 | 36.70] loss=0.13 avg=0.13
# [5008 | 37.61] loss=0.08 avg=0.13
# [5009 | 38.51] loss=0.18 avg=0.13
# [5010 | 39.41] loss=0.18 avg=0.14
# [5011 | 40.32] loss=0.07 avg=0.13
# [5012 | 41.23] loss=0.14 avg=0.13
# [5013 | 42.13] loss=0.07 avg=0.13
# [5014 | 43.03] loss=0.09 avg=0.12
# [5015 | 43.94] loss=0.07 avg=0.12
# [5016 | 44.84] loss=0.15 avg=0.12
# [5017 | 45.74] loss=0.10 avg=0.12
# [5018 | 46.65] loss=0.13 avg=0.12
# [5019 | 47.55] loss=0.15 avg=0.12
# [5020 | 48.45] loss=0.07 avg=0.12
# [5021 | 49.35] loss=0.16 avg=0.12
# [5022 | 50.26] loss=0.23 avg=0.13
# [5023 | 51.16] loss=0.14 avg=0.13
# [5024 | 52.07] loss=0.19 avg=0.13
# [5025 | 52.97] loss=0.11 avg=0.13
# [5026 | 53.87] loss=0.11 avg=0.13
# [5027 | 54.77] loss=0.11 avg=0.13
# [5028 | 55.68] loss=0.17 avg=0.13
# [5029 | 56.58] loss=0.12 avg=0.13
# [5030 | 57.48] loss=0.16 avg=0.13
# [5031 | 58.39] loss=0.04 avg=0.13
# [5032 | 59.29] loss=0.07 avg=0.13
# [5033 | 60.20] loss=0.09 avg=0.12
# [5034 | 61.10] loss=0.22 avg=0.13
# [5035 | 62.00] loss=0.14 avg=0.13
# [5036 | 62.91] loss=0.14 avg=0.13
# [5037 | 63.81] loss=0.10 avg=0.13
# [5038 | 64.72] loss=0.06 avg=0.13
# [5039 | 65.62] loss=0.07 avg=0.12
# [5040 | 66.52] loss=0.10 avg=0.12
# [5041 | 67.43] loss=0.08 avg=0.12
# [5042 | 68.33] loss=0.16 avg=0.12
# [5043 | 69.23] loss=0.14 avg=0.12
# [5044 | 70.14] loss=0.13 avg=0.12
# [5045 | 71.04] loss=0.07 avg=0.12
# [5046 | 71.95] loss=0.12 avg=0.12
# [5047 | 72.85] loss=0.14 avg=0.12
# [5048 | 73.75] loss=0.15 avg=0.12
# [5049 | 74.66] loss=0.13 avg=0.12
# [5050 | 75.56] loss=0.12 avg=0.12
# [5051 | 76.46] loss=0.12 avg=0.12
# [5052 | 77.37] loss=0.18 avg=0.12
# [5053 | 78.27] loss=0.14 avg=0.12
# [5054 | 79.17] loss=0.09 avg=0.12
# [5055 | 80.08] loss=0.12 avg=0.12
# [5056 | 80.98] loss=0.11 avg=0.12
# [5057 | 81.89] loss=0.17 avg=0.12
# [5058 | 82.79] loss=0.17 avg=0.13
# [5059 | 83.69] loss=0.08 avg=0.12
# [5060 | 84.60] loss=0.09 avg=0.12
# [5061 | 85.50] loss=0.09 avg=0.12
# [5062 | 86.40] loss=0.22 avg=0.13
# [5063 | 87.31] loss=0.16 avg=0.13
# [5064 | 88.21] loss=0.10 avg=0.13
# [5065 | 89.12] loss=0.11 avg=0.13
# [5066 | 90.02] loss=0.05 avg=0.12
# [5067 | 90.92] loss=0.15 avg=0.12
# [5068 | 91.83] loss=0.09 avg=0.12
# [5069 | 92.73] loss=0.12 avg=0.12
# [5070 | 93.63] loss=0.25 avg=0.13
# [5071 | 94.54] loss=0.10 avg=0.13
# [5072 | 95.44] loss=0.44 avg=0.13
# [5073 | 96.34] loss=0.08 avg=0.13
# [5074 | 97.25] loss=0.11 avg=0.13
# [5075 | 98.15] loss=0.08 avg=0.13
# [5076 | 99.05] loss=0.11 avg=0.13
# [5077 | 99.96] loss=0.05 avg=0.13
# [5078 | 100.86] loss=0.06 avg=0.13
# [5079 | 101.77] loss=0.07 avg=0.13
# [5080 | 102.68] loss=0.08 avg=0.12
# [5081 | 103.58] loss=0.12 avg=0.12
# [5082 | 104.48] loss=0.16 avg=0.12
# [5083 | 105.39] loss=0.11 avg=0.12
# [5084 | 106.29] loss=0.15 avg=0.13
# [5085 | 107.19] loss=0.22 avg=0.13
# [5086 | 108.10] loss=0.08 avg=0.13
# [5087 | 109.00] loss=0.12 avg=0.13
# [5088 | 109.90] loss=0.13 avg=0.13
# [5089 | 110.81] loss=0.10 avg=0.13
# [5090 | 111.71] loss=0.06 avg=0.12
# [5091 | 112.61] loss=0.18 avg=0.13
# [5092 | 113.52] loss=0.18 avg=0.13
# [5093 | 114.42] loss=0.19 avg=0.13
# [5094 | 115.32] loss=0.09 avg=0.13
# [5095 | 116.23] loss=0.13 avg=0.13
# [5096 | 117.13] loss=0.18 avg=0.13
# [5097 | 118.04] loss=0.12 avg=0.13
# [5098 | 118.95] loss=0.13 avg=0.13
# [5099 | 119.85] loss=0.10 avg=0.13
# [5100 | 120.76] loss=0.05 avg=0.13
# ======== SAMPLE 1 ========
# �turing test” used determine whether software legal encode properties embedd linearly irreducible properties words programs need able “speak machine”—and conversely conversely desire need able “pretend speak machine”—their programs cannot produce outputs reality programs simply cannot think like humans since beginning neural networks 1980s successful producing outputs Turing test suite properties encoding learning1 take job losses due automation often result job losses due cognitive decline automation however automation may temporary change traditional methods employment—such loss jobs following automation legal mandated automatability—often viewed sources automation substitute human labor b workplace also desirable prevent workplace culture change typical background function human labor—the kind worked least desirable outcomes automation many machines become much energy efficient since 1980s primary goal workplace automation substitute human labor involves combination combination tasks human workers perform workplace automation substitute whol human labor perform—and change comes responsibilities employers governments societal factors society requires humans perform workplace automation include decisions need made concerning individuals tasks may seen ethical responsibility close colleagues family members society require ethical skil require motivation autonomy ability trustworthiness work human people robots require ethical reasoning robot software programs need explainable accountable accountable people society needs trust highly cooperative robots operate humanlike humans trust humans robots need explainable trustworthy robots require motivation equal difficult people humans trust robots vice versa people humans emotional attachment robots difficult break even under recognized circumstances people show empathy humans emotional attachmentels even people know great love care robots outcome unpredictable difficult Neonatal units unclear dividing line simple case autonomous weapon deep learning system may legal take consideration following section autonomous weapon systems gun laws subject area studies legislation conflict little research done autonomous weapons systems since well developed gun laws subject extensive prohibition gun show prevalent use banned device identification traceability makes easy trace mobilization people mobilized place fear violence even gun stolen used person threat life one motivations might considered legal long gun registration universal background checks done ongoing background checks make illegal guns easily traced back people may even charged violation background check result bans gun show restrictions gun show invites gun theft even gun theft permit holders firearms licensees restricted ability transport firearms person may challenge identification even one year federal background checks “Colorado city bans highcapacity magazines” httpswwwthevergecom20183191313118832highcapacitymagazinestateofart Coloradoendment6565highammunitionsafetymeasureshtml nye v california background checks httpswwwthevergecom2018319131188321013822 Reloading restrictions gun show also common measure restricting magazine capacity assault weapons designed capability rapid disassembling gun stolen police stop sign enforcement surprise access weapon data owner thirdparty vendors heartening find gun show registration move forward goal developing robust comprehensive legal system gun violence prevention smart gun technology long ard gun laws come background checks required prior importation gun subject years legal ramifications gun show registration move forward example background checks quickly became standard undergo rigorous review upheld crucial component national instantiated standards set standards integrity procedural fairness along design notion procedural fairness requires meaningful input government interest federalism often seen protecting rights individuals within scope us legal system along substantive legal rul ...
#
# [5101 | 141.14] loss=0.07 avg=0.12
# [5102 | 142.04] loss=0.14 avg=0.13
# [5103 | 142.94] loss=0.15 avg=0.13
# [5104 | 143.85] loss=0.16 avg=0.13
# [5105 | 144.76] loss=0.06 avg=0.13
# [5106 | 145.66] loss=0.13 avg=0.13
# [5107 | 146.57] loss=0.27 avg=0.13
# [5108 | 147.47] loss=0.08 avg=0.13
# [5109 | 148.37] loss=0.08 avg=0.13
# [5110 | 149.28] loss=0.10 avg=0.13
# [5111 | 150.18] loss=0.10 avg=0.13
# [5112 | 151.08] loss=0.06 avg=0.12
# [5113 | 151.99] loss=0.20 avg=0.13
# [5114 | 152.89] loss=0.09 avg=0.12
# [5115 | 153.80] loss=0.12 avg=0.12
# [5116 | 154.70] loss=0.08 avg=0.12
# [5117 | 155.60] loss=0.06 avg=0.12
# [5118 | 156.50] loss=0.08 avg=0.12
# [5119 | 157.41] loss=0.14 avg=0.12
# [5120 | 158.31] loss=0.10 avg=0.12
# [5121 | 159.21] loss=0.07 avg=0.12
# [5122 | 160.12] loss=0.09 avg=0.12
# [5123 | 161.02] loss=0.08 avg=0.12
# [5124 | 161.92] loss=0.21 avg=0.12
# [5125 | 162.83] loss=0.12 avg=0.12
# [5126 | 163.73] loss=0.15 avg=0.12
# [5127 | 164.63] loss=0.17 avg=0.12
# [5128 | 165.54] loss=0.13 avg=0.12
# [5129 | 166.44] loss=0.11 avg=0.12
# [5130 | 167.35] loss=0.07 avg=0.12
# [5131 | 168.25] loss=0.08 avg=0.12
# [5132 | 169.15] loss=0.12 avg=0.12
# [5133 | 170.05] loss=0.10 avg=0.12
# [5134 | 170.96] loss=0.26 avg=0.12
# [5135 | 171.86] loss=0.10 avg=0.12
# [5136 | 172.76] loss=0.14 avg=0.12
# [5137 | 173.67] loss=0.15 avg=0.12
# [5138 | 174.57] loss=0.16 avg=0.12
# [5139 | 175.48] loss=0.24 avg=0.13
# [5140 | 176.38] loss=0.13 avg=0.13
# [5141 | 177.28] loss=0.09 avg=0.13
# [5142 | 178.19] loss=0.07 avg=0.12
# [5143 | 179.09] loss=0.13 avg=0.12
# [5144 | 180.00] loss=0.15 avg=0.12
# [5145 | 180.90] loss=0.15 avg=0.13
# [5146 | 181.80] loss=0.06 avg=0.12
# [5147 | 182.70] loss=0.06 avg=0.12
# [5148 | 183.61] loss=0.20 avg=0.12
# [5149 | 184.51] loss=0.13 avg=0.12
# [5150 | 185.42] loss=0.14 avg=0.12
# [5151 | 186.32] loss=0.12 avg=0.12
# [5152 | 187.22] loss=0.10 avg=0.12
# [5153 | 188.13] loss=0.13 avg=0.12
# [5154 | 189.03] loss=0.07 avg=0.12
# [5155 | 189.94] loss=0.29 avg=0.13
# [5156 | 190.84] loss=0.08 avg=0.13
# [5157 | 191.74] loss=0.08 avg=0.12
# [5158 | 192.65] loss=0.09 avg=0.12
# [5159 | 193.55] loss=0.19 avg=0.13
# [5160 | 194.45] loss=0.10 avg=0.12
# [5161 | 195.35] loss=0.06 avg=0.12
# [5162 | 196.26] loss=0.14 avg=0.12
# [5163 | 197.16] loss=0.13 avg=0.12
# [5164 | 198.07] loss=0.13 avg=0.12
# [5165 | 198.97] loss=0.10 avg=0.12
# [5166 | 199.87] loss=0.11 avg=0.12
# [5167 | 200.78] loss=0.16 avg=0.12
# [5168 | 201.68] loss=0.07 avg=0.12
# [5169 | 202.58] loss=0.08 avg=0.12
# [5170 | 203.48] loss=0.09 avg=0.12
# [5171 | 204.39] loss=0.13 avg=0.12
# [5172 | 205.29] loss=0.15 avg=0.12
# [5173 | 206.20] loss=0.06 avg=0.12
# [5174 | 207.10] loss=0.07 avg=0.12
# [5175 | 208.01] loss=0.17 avg=0.12
# [5176 | 208.91] loss=0.08 avg=0.12
# [5177 | 209.82] loss=0.33 avg=0.12
# [5178 | 210.72] loss=0.14 avg=0.12
# [5179 | 211.62] loss=0.07 avg=0.12
# [5180 | 212.53] loss=0.03 avg=0.12
# [5181 | 213.43] loss=0.09 avg=0.12
# [5182 | 214.34] loss=0.14 avg=0.12
# [5183 | 215.24] loss=0.11 avg=0.12
# [5184 | 216.14] loss=0.09 avg=0.12
# [5185 | 217.05] loss=0.10 avg=0.12
# [5186 | 217.95] loss=0.07 avg=0.12
# [5187 | 218.85] loss=0.14 avg=0.12
# [5188 | 219.76] loss=0.09 avg=0.12
# [5189 | 220.66] loss=0.17 avg=0.12
# [5190 | 221.57] loss=0.22 avg=0.12
# [5191 | 222.47] loss=0.18 avg=0.12
# [5192 | 223.37] loss=0.09 avg=0.12
# [5193 | 224.28] loss=0.16 avg=0.12
# [5194 | 225.18] loss=0.12 avg=0.12
# [5195 | 226.08] loss=0.08 avg=0.12
# [5196 | 226.99] loss=0.11 avg=0.12
# [5197 | 227.89] loss=0.08 avg=0.12
# [5198 | 228.80] loss=0.18 avg=0.12
# [5199 | 229.70] loss=0.11 avg=0.12
# [5200 | 230.61] loss=0.13 avg=0.12
# Saving /content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1/model-5200
# ======== SAMPLE 1 ========
#  involving realtime data collection social media also increases likelihood ai systems deployed intimate relationships area already taken care complex social psychological labor one results may feel extent control personal data lives meaningful sense understood7 psychological theory understanding art mind let alone robots8 impacts existential risks may also important consideration given rapid technological change also possible approaches9 explore consequences potential approach exploring understanding art mind using approach take ethical considerations several ethical principles explicitly defined smartness ethical virtue seeking apply ethical principles ai systems finding applicability ethical rules ai systems found either singly words “trustworthy” “need trust” unambiguous terms often accompanied definitions memory concept sense self ai systems need store learn previous acts conduct learn prevent behavior correlate specific ethical principles meaning ethical principles seek prevent ai systems subsequently used ai systems useful lawful purposes example address need ensure systems cannot used dishonest individuals meeting specific requirements safety data another example ethical ai used assist military personnel conducting joint military operations legal required conduct legal defined engaged military objectives “as little risk possible” interna tional international law requires distinction permissible military operations legal defined support otherwise prohibited operations absent legal definition clearly identifies underlying legal meaning “legal considered adverse takeonement” defined “when doubt arises whether particular device lawful military application” see interna tional law adapted consider certain military environments vulnerable conditions may generate circumstances understood human authority military commanders decide whether place trust autonomous systems ai systems question also rest much philosophical rather technical debate subject area remain resolved philosophical question whether human control control control indeed control ai systems still far needed acknowledge must place emphasis control systems— particularly development ai systems—having ultimate decision authority how—as advocate use ai systems means best control outcomes culture evolves human users develop use ai systems must ped agogical policy issues arise design systems—including appropriate forms regulation logging auditing—that culture develops appropriately address cultures ethics relate technologies also critical many ethics involve problems related design development deployment ai systems—including issues related accountability ethics lack culture openness thus development ai systems may require strict compliance laws legal rules including appropriate permissions losses due nonperformance occur example due lack culture accountability ai systems may result higher risk compliance laws legal rules including accountability ethics cannot left handed die care fol lowses lack culture openness ai systems thus need strict compliance culturewhatever means codes ethics ai may difficult read explain meaningful accountability ai systems however ai systems developed help mea sures promote learning behavior so fidelity cultural engineering approach must ensconced design development ai systems far hands off informational technology culture thus responsible ai ultimately responsible ai means oversight allows governance cope lack culture accountability requires researchers developers ai systems ensure ai systems fulfilled purpose testing came answer design problem testing used support decisionmaking practice needed integrate approach cultural context research development work ensure compliance human values due process rights contestation rights unbiased tribunal particularly important cultural context research development work underlies creativity individual human beings work seen iterative refinement away values step done rather seen product technology developed ...
#
# [5201 | 260.25] loss=0.07 avg=0.12
# [5202 | 261.16] loss=0.11 avg=0.12
# [5203 | 262.06] loss=0.09 avg=0.12
# [5204 | 262.97] loss=0.18 avg=0.12
# [5205 | 263.88] loss=0.13 avg=0.12
# [5206 | 264.79] loss=0.10 avg=0.12
# [5207 | 265.70] loss=0.14 avg=0.12
# [5208 | 266.61] loss=0.10 avg=0.12
# [5209 | 267.52] loss=0.05 avg=0.12
# [5210 | 268.42] loss=0.10 avg=0.12
# [5211 | 269.33] loss=0.14 avg=0.12
# [5212 | 270.24] loss=0.16 avg=0.12
# [5213 | 271.14] loss=0.06 avg=0.12
# [5214 | 272.04] loss=0.10 avg=0.12
# [5215 | 272.95] loss=0.10 avg=0.12
# [5216 | 273.86] loss=0.10 avg=0.12
# [5217 | 274.76] loss=0.12 avg=0.12
# [5218 | 275.67] loss=0.18 avg=0.12
# [5219 | 276.58] loss=0.12 avg=0.12
# [5220 | 277.48] loss=0.08 avg=0.12
# [5221 | 278.39] loss=0.17 avg=0.12
# [5222 | 279.29] loss=0.10 avg=0.12
# [5223 | 280.19] loss=0.07 avg=0.12
# [5224 | 281.10] loss=0.07 avg=0.12
# [5225 | 282.01] loss=0.12 avg=0.12
# [5226 | 282.91] loss=0.20 avg=0.12
# [5227 | 283.82] loss=0.10 avg=0.12
# [5228 | 284.73] loss=0.16 avg=0.12
# [5229 | 285.63] loss=0.13 avg=0.12
# [5230 | 286.54] loss=0.15 avg=0.12
# [5231 | 287.44] loss=0.15 avg=0.12
# [5232 | 288.35] loss=0.12 avg=0.12
# [5233 | 289.25] loss=0.13 avg=0.12
# [5234 | 290.16] loss=0.16 avg=0.12
# [5235 | 291.06] loss=0.08 avg=0.12
# [5236 | 291.96] loss=0.11 avg=0.12
# [5237 | 292.87] loss=0.25 avg=0.12
# [5238 | 293.77] loss=0.09 avg=0.12
# [5239 | 294.67] loss=0.07 avg=0.12
# [5240 | 295.58] loss=0.07 avg=0.12
# [5241 | 296.48] loss=0.11 avg=0.12
# [5242 | 297.39] loss=0.09 avg=0.12
# [5243 | 298.29] loss=0.13 avg=0.12
# [5244 | 299.19] loss=0.17 avg=0.12
# [5245 | 300.10] loss=0.07 avg=0.12
# [5246 | 301.00] loss=0.11 avg=0.12
# [5247 | 301.90] loss=0.08 avg=0.12
# [5248 | 302.81] loss=0.11 avg=0.12
# [5249 | 303.71] loss=0.06 avg=0.12
# [5250 | 304.62] loss=0.09 avg=0.12
# [5251 | 305.52] loss=0.08 avg=0.12
# [5252 | 306.42] loss=0.22 avg=0.12
# [5253 | 307.33] loss=0.09 avg=0.12
# [5254 | 308.23] loss=0.14 avg=0.12
# [5255 | 309.14] loss=0.06 avg=0.12
# [5256 | 310.04] loss=0.12 avg=0.12
# [5257 | 310.94] loss=0.20 avg=0.12
# [5258 | 311.85] loss=0.10 avg=0.12
# [5259 | 312.75] loss=0.25 avg=0.12
# [5260 | 313.65] loss=0.07 avg=0.12
# [5261 | 314.56] loss=0.09 avg=0.12
# [5262 | 315.46] loss=0.14 avg=0.12
# [5263 | 316.37] loss=0.15 avg=0.12
# [5264 | 317.27] loss=0.11 avg=0.12
# [5265 | 318.18] loss=0.13 avg=0.12
# [5266 | 319.08] loss=0.07 avg=0.12
# [5267 | 319.99] loss=0.18 avg=0.12
# [5268 | 320.89] loss=0.20 avg=0.12
# [5269 | 321.79] loss=0.15 avg=0.12
# [5270 | 322.70] loss=0.15 avg=0.12
# [5271 | 323.60] loss=0.26 avg=0.12
# [5272 | 324.51] loss=0.12 avg=0.12
# [5273 | 325.41] loss=0.07 avg=0.12
# [5274 | 326.32] loss=0.07 avg=0.12
# [5275 | 327.22] loss=0.18 avg=0.12
# [5276 | 328.13] loss=0.11 avg=0.12
# [5277 | 329.03] loss=0.12 avg=0.12
# [5278 | 329.94] loss=0.20 avg=0.12
# [5279 | 330.84] loss=0.16 avg=0.12
# [5280 | 331.74] loss=0.24 avg=0.13
# [5281 | 332.65] loss=0.13 avg=0.13
# [5282 | 333.55] loss=0.17 avg=0.13
# [5283 | 334.45] loss=0.05 avg=0.13
# [5284 | 335.36] loss=0.10 avg=0.12
# [5285 | 336.26] loss=0.16 avg=0.13
# [5286 | 337.17] loss=0.07 avg=0.12
# [5287 | 338.07] loss=0.29 avg=0.13
# [5288 | 338.97] loss=0.05 avg=0.13
# [5289 | 339.88] loss=0.31 avg=0.13
# [5290 | 340.78] loss=0.09 avg=0.13
# [5291 | 341.68] loss=0.09 avg=0.13
# [5292 | 342.59] loss=0.12 avg=0.13
# [5293 | 343.49] loss=0.07 avg=0.13
# [5294 | 344.39] loss=0.17 avg=0.13
# [5295 | 345.30] loss=0.18 avg=0.13
# [5296 | 346.20] loss=0.12 avg=0.13
# [5297 | 347.11] loss=0.13 avg=0.13
# [5298 | 348.01] loss=0.08 avg=0.13
# [5299 | 348.91] loss=0.07 avg=0.13
# [5300 | 349.82] loss=0.12 avg=0.13
# ======== SAMPLE 1 ========
#  tertacynics –accountability –race gender –cardiovascular risk behavior –counselling –cornerstone ethics –contextualization –creationism –contextual security –contextual think –the crisis risk –of robots –and machines –autonomy –race gender –archetype artifact –contextualization –creationism – Custodian duty –commissariness –race gender –cardiovascular risk behavior –computational statistics commons –cambridge analytica –responsibility –race gender –cardiovascular risk behavior –computational ethics –contextualization –creationism – consent ––computerized lottery cover image contest see also deception ––disengagement responsibility –race gender –introduction –current limitations –diversity –6n8 privacy –6n8 ai origins –6n8 data modeling –6n8 ethical alignment –6n8 emily –race gender –see also james power ––enlightenment –women –ensmenger nathan edwards lilian –enthusiastic consent eeg see electroencephalogram eod see explosive ordinance disposal egalitarianism see also efficiency endorphin production –enlightenment –women –ensmenger nathan edwards lilian –enthusiastic consent eeg see electroencephalogram ethical guidelines intelligent assistant redistribute wealth society intelligent assistants redistribute wealth life intel igent assistant seems reflect values diminishing returns anxiety capitalism intelligent assistants could end suffering techno logical advances intelligence ai market value intelligence algorithms intelligence used justification deploying idea vast computational power ai abletoday’s conventional intel igence architecture ai systemsagine buildings connected informa tion sensors augmented virtual reality augmented physical worldbuilding informa tion systemsagine builtings connected physical world smart cities artificial intelligence appli cants aggregate correlatively modify surveil ance selfdriving cars virtual realities augmented physical world smart enough monitor mood urban guerrillas super’computers monitor mood inform interventions level climate supercomputers keep pace superintelligent ai would seem likely usa intelligence investigating list questions1 would along lines predicted intelligent assistant system taken example assumed male gender intelligent assistant system probabi cut male gender persons social emotional regulation expert marxian formula mod els effac e tympan subject supplications michael wheeler autonomous vehicle revolutionizing urban planning martin liemer “the urban cybernetics implementation augmented reality urban planning” research foundations principles urban life ethics –christopher russel berlin springer –christopher russel boden “public procurement urbanism” cybernetics systems chapter ai moral agent explained lines ethical responsibilities ai humancentered approach ai ethics made vulnerable3 given fact ai agent concept developed categorical imperative imperative reinforce existing social arrangements protection ai moral agent research shown ethical responsibilities ai agent concept amply demonstrated responsible parties whenever possible already anticipate need rights intervene new situations increased amotivation demand ai agent ensure responsible ai mod els whenever possible lan guage would explain responsible ai fact someone’s wellbeing harmed suffers increased amotivation demand ai agent experience increased wellbeing make sense attribute wellbeing evolved agent system human beings make sense attribute wellbeing arises lifelong condition ai relationship us decide want ai behave normative good way human lovers deserve likeminded autonomous agents ai systems often desire avoid taking care ethical properties ai real psychological properties ai human lovers hack human lovers hack computer systems seek mitigate negative utilitarian biases ai systems must designed need loving relationship minimal autonomy however programmed love interest artificial partner system encourages us constantly monitoring progress understand lack autonomy often perceived major constraint ai ethics tra ...
#
# [5301 | 368.83] loss=0.16 avg=0.13
# [5302 | 369.73] loss=0.14 avg=0.13
# [5303 | 370.64] loss=0.16 avg=0.13
# [5304 | 371.54] loss=0.19 avg=0.13
# [5305 | 372.45] loss=0.19 avg=0.13
# [5306 | 373.35] loss=0.06 avg=0.13
# [5307 | 374.26] loss=0.07 avg=0.13
# [5308 | 375.16] loss=0.13 avg=0.13
# [5309 | 376.07] loss=0.12 avg=0.13
# [5310 | 376.97] loss=0.12 avg=0.13
# [5311 | 377.88] loss=0.15 avg=0.13
# [5312 | 378.78] loss=0.07 avg=0.13
# [5313 | 379.68] loss=0.09 avg=0.13
# [5314 | 380.59] loss=0.10 avg=0.13
# [5315 | 381.49] loss=0.05 avg=0.12
# [5316 | 382.40] loss=0.07 avg=0.12
# [5317 | 383.30] loss=0.28 avg=0.13
# [5318 | 384.20] loss=0.04 avg=0.13
# [5319 | 385.11] loss=0.14 avg=0.13
# [5320 | 386.01] loss=0.09 avg=0.12
# [5321 | 386.91] loss=0.15 avg=0.13
# [5322 | 387.82] loss=0.08 avg=0.12
# [5323 | 388.72] loss=0.03 avg=0.12
# [5324 | 389.63] loss=0.08 avg=0.12
# [5325 | 390.53] loss=0.14 avg=0.12
# [5326 | 391.44] loss=0.07 avg=0.12
# [5327 | 392.34] loss=0.13 avg=0.12
# [5328 | 393.25] loss=0.12 avg=0.12
# [5329 | 394.16] loss=0.29 avg=0.12
# [5330 | 395.07] loss=0.15 avg=0.12
# [5331 | 395.97] loss=0.11 avg=0.12
# [5332 | 396.88] loss=0.14 avg=0.12
# [5333 | 397.78] loss=0.08 avg=0.12
# [5334 | 398.69] loss=0.05 avg=0.12
# [5335 | 399.60] loss=0.15 avg=0.12
# [5336 | 400.51] loss=0.12 avg=0.12
# [5337 | 401.42] loss=0.13 avg=0.12
# [5338 | 402.32] loss=0.04 avg=0.12
# [5339 | 403.23] loss=0.12 avg=0.12
# [5340 | 404.14] loss=0.07 avg=0.12
# [5341 | 405.04] loss=0.21 avg=0.12
# [5342 | 405.94] loss=0.19 avg=0.12
# [5343 | 406.85] loss=0.04 avg=0.12
# [5344 | 407.76] loss=0.08 avg=0.12
# [5345 | 408.66] loss=0.04 avg=0.12
# [5346 | 409.56] loss=0.08 avg=0.12
# [5347 | 410.47] loss=0.04 avg=0.12
# [5348 | 411.37] loss=0.12 avg=0.12
# [5349 | 412.28] loss=0.25 avg=0.12
# [5350 | 413.18] loss=0.09 avg=0.12
# [5351 | 414.08] loss=0.18 avg=0.12
# [5352 | 414.99] loss=0.10 avg=0.12
# [5353 | 415.90] loss=0.08 avg=0.12
# [5354 | 416.80] loss=0.08 avg=0.12
# [5355 | 417.70] loss=0.10 avg=0.12
# [5356 | 418.61] loss=0.07 avg=0.12
# [5357 | 419.51] loss=0.18 avg=0.12
# [5358 | 420.42] loss=0.14 avg=0.12
# [5359 | 421.32] loss=0.19 avg=0.12
# [5360 | 422.23] loss=0.09 avg=0.12
# [5361 | 423.13] loss=0.06 avg=0.12
# [5362 | 424.03] loss=0.10 avg=0.12
# [5363 | 424.94] loss=0.11 avg=0.12
# [5364 | 425.84] loss=0.15 avg=0.12
# [5365 | 426.75] loss=0.24 avg=0.12
# [5366 | 427.65] loss=0.06 avg=0.12
# [5367 | 428.56] loss=0.07 avg=0.12
# [5368 | 429.46] loss=0.13 avg=0.12
# [5369 | 430.36] loss=0.08 avg=0.12
# [5370 | 431.27] loss=0.19 avg=0.12
# [5371 | 432.17] loss=0.09 avg=0.12
# [5372 | 433.08] loss=0.09 avg=0.12
# [5373 | 433.98] loss=0.09 avg=0.12
# [5374 | 434.89] loss=0.19 avg=0.12
# [5375 | 435.79] loss=0.24 avg=0.12
# [5376 | 436.69] loss=0.34 avg=0.12
# [5377 | 437.60] loss=0.09 avg=0.12
# [5378 | 438.50] loss=0.04 avg=0.12
# [5379 | 439.40] loss=0.14 avg=0.12
# [5380 | 440.31] loss=0.09 avg=0.12
# [5381 | 441.21] loss=0.11 avg=0.12
# [5382 | 442.12] loss=0.17 avg=0.12
# [5383 | 443.02] loss=0.10 avg=0.12
# [5384 | 443.92] loss=0.14 avg=0.12
# [5385 | 444.83] loss=0.11 avg=0.12
# [5386 | 445.73] loss=0.10 avg=0.12
# [5387 | 446.64] loss=0.12 avg=0.12
# [5388 | 447.54] loss=0.18 avg=0.12
# [5389 | 448.44] loss=0.16 avg=0.12
# [5390 | 449.35] loss=0.15 avg=0.12
# [5391 | 450.25] loss=0.18 avg=0.12
# [5392 | 451.15] loss=0.15 avg=0.13
# [5393 | 452.06] loss=0.10 avg=0.13
# [5394 | 452.96] loss=0.21 avg=0.13
# [5395 | 453.87] loss=0.05 avg=0.13
# [5396 | 454.77] loss=0.11 avg=0.12
# [5397 | 455.68] loss=0.05 avg=0.12
# [5398 | 456.58] loss=0.09 avg=0.12
# [5399 | 457.48] loss=0.10 avg=0.12
# [5400 | 458.39] loss=0.15 avg=0.12
# ======== SAMPLE 1 ========
# cifici ties ethical issues ai example ai used military purposes unclear whether intended negative often ambiguous whether use military neutral ity occurs similarly murk re dart universal declaration human rights udhr adopted december korea house lords select committee artificial intelligence korea hk nd public consultation held artificial intelligence korea hangzhou geoff spencer “the ethical ethical framework good ai society” ai global south designing worlds “ai means technology neutral determines social economic context determines agenda artificial intelligence” keio university juda k–kees ifeoma “the social impact assessment strategic framework ai” ai global south designing worlds “ai means technology neutral determines social economic context” keio university juda k–kees ifeoma “ assessment social impact assessment strategic framework ai” korea social research center httpricenotoreasocialbranchingubiquitousapplebusinessinsightspepto changesoftbankrosoftbankrointroducingaiethics strategicplan january httpskoreabudgetedsoftbankroboticsstrategypepto31aaa18de might see anbangladeshi roboticists form association computing machinery humans “enhanced intelligence” principle design draws upon idea even biology intelligence physical capabilities slightly differently heightened sensitivity information communication intelligence principle drawing upon something—perhaps even aAAAAa—is sentient ai principle sight agi principle excused stil ai used military purposes unknown whether ful autonomous ai agents form threat posed local populations easy though distinction clear humansmartians ontario iguana frog genes mucus defense system id –and –anime robot development report oecd regulatory standards oecd regulatory governance irc langprc httpsdigitalcommonslangrieecdmedianet5824r epoch201712 vjimbeetSingh kusim sharat kusim graeme ritchie h thompson “the ethical issues relationship artificial entities” journal ethics –290n15 social organization october oecd publishing new york curio “omics society” –httpsdoiorg101038505347inianetomics jordan thomas adrian weller “research priorities autonomous intelligent systems” published ahead print january indigenous artificial entities” indigenous entities ––f wellcome handbook comparative perspective new york basic books perspectives ethics ai philosophy mind new york john wiley sons r vaggo “public perception automated discrimination” proceedings 1st conference fairness accountability transparency –wellcome handbook jurisprudence social failure modes technology ethics ai philosophy ifeoma ajunwa rachel schlund current state use ai technology operative context public criminal law pasquale scott james fields origins ai scott andrew press new york basic books perspectives ethics ai scott moral machines teaching robots right wrong oxford oxford university press wellcome handbook jurisprudence social failure modes technology ethics ai scott moral machine learning learning facebook datacenter infrastructure intelligence law basic negativesum result platforms dry technical definitions lacking transparency hence risky overstatements technological systems prone sociotechnical instability underestimation overestimations existential threats using overly optimistic timetel ing classifications risks digital technology considered “devastating” kinds farreaching consequences risk inclusion nonhuman entities subject increasingly invasive forms datasharing cases example airport cybersecurity facial recognition systems severely limited range practical control facial recognition systems “handled” require human intervention order function properly coded internationalogl § §–general comment nos ––international adopt general comment nos gdpr §–general comment nos gdpr nhs future life report gdpr international covenant civil political rights france six months later united nations under consideration adopt general comment nos internet site httpswwwgdprorg gdprindexphp lambertinFORMATION ajunwa “the paradox automation antib ...
#
# [5401 | 477.98] loss=0.20 avg=0.12
# [5402 | 478.89] loss=0.16 avg=0.13
# [5403 | 479.79] loss=0.09 avg=0.12
# [5404 | 480.70] loss=0.05 avg=0.12
# [5405 | 481.61] loss=0.10 avg=0.12
# [5406 | 482.51] loss=0.09 avg=0.12
# [5407 | 483.41] loss=0.05 avg=0.12
# [5408 | 484.32] loss=0.09 avg=0.12
# [5409 | 485.22] loss=0.11 avg=0.12
# [5410 | 486.12] loss=0.15 avg=0.12
# [5411 | 487.02] loss=0.14 avg=0.12
# [5412 | 487.93] loss=0.08 avg=0.12
# [5413 | 488.83] loss=0.06 avg=0.12
# [5414 | 489.73] loss=0.11 avg=0.12
# [5415 | 490.64] loss=0.16 avg=0.12
# [5416 | 491.54] loss=0.13 avg=0.12
# [5417 | 492.45] loss=0.15 avg=0.12
# [5418 | 493.35] loss=0.09 avg=0.12
# [5419 | 494.25] loss=0.08 avg=0.12
# [5420 | 495.16] loss=0.14 avg=0.12
# [5421 | 496.06] loss=0.15 avg=0.12
# [5422 | 496.96] loss=0.21 avg=0.12
# [5423 | 497.87] loss=0.09 avg=0.12
# [5424 | 498.77] loss=0.16 avg=0.12
# [5425 | 499.67] loss=0.14 avg=0.12
# [5426 | 500.58] loss=0.15 avg=0.12
# [5427 | 501.48] loss=0.10 avg=0.12
# [5428 | 502.39] loss=0.05 avg=0.12
# [5429 | 503.29] loss=0.09 avg=0.12
# [5430 | 504.20] loss=0.15 avg=0.12
# [5431 | 505.10] loss=0.31 avg=0.12
# [5432 | 506.01] loss=0.07 avg=0.12
# [5433 | 506.91] loss=0.05 avg=0.12
# [5434 | 507.82] loss=0.11 avg=0.12
# [5435 | 508.72] loss=0.18 avg=0.12
# [5436 | 509.63] loss=0.08 avg=0.12
# [5437 | 510.53] loss=0.13 avg=0.12
# [5438 | 511.44] loss=0.11 avg=0.12
# [5439 | 512.34] loss=0.09 avg=0.12
# [5440 | 513.25] loss=0.13 avg=0.12
# [5441 | 514.15] loss=0.12 avg=0.12
# [5442 | 515.06] loss=0.18 avg=0.12
# [5443 | 515.97] loss=0.08 avg=0.12
# [5444 | 516.87] loss=0.12 avg=0.12
# [5445 | 517.78] loss=0.06 avg=0.12
# [5446 | 518.68] loss=0.15 avg=0.12
# [5447 | 519.58] loss=0.10 avg=0.12
# [5448 | 520.49] loss=0.11 avg=0.12
# [5449 | 521.39] loss=0.13 avg=0.12
# [5450 | 522.30] loss=0.05 avg=0.12
# [5451 | 523.20] loss=0.11 avg=0.12
# [5452 | 524.11] loss=0.19 avg=0.12
# [5453 | 525.02] loss=0.15 avg=0.12
# [5454 | 525.92] loss=0.09 avg=0.12
# [5455 | 526.82] loss=0.06 avg=0.12
# [5456 | 527.73] loss=0.05 avg=0.12
# [5457 | 528.63] loss=0.28 avg=0.12
# [5458 | 529.54] loss=0.09 avg=0.12
# [5459 | 530.44] loss=0.18 avg=0.12
# [5460 | 531.34] loss=0.10 avg=0.12
# [5461 | 532.25] loss=0.10 avg=0.12
# [5462 | 533.15] loss=0.07 avg=0.12
# [5463 | 534.06] loss=0.07 avg=0.12
# [5464 | 534.96] loss=0.10 avg=0.12
# [5465 | 535.87] loss=0.09 avg=0.12
# [5466 | 536.77] loss=0.08 avg=0.12
# [5467 | 537.67] loss=0.18 avg=0.12
# [5468 | 538.58] loss=0.09 avg=0.12
# [5469 | 539.49] loss=0.10 avg=0.12
# [5470 | 540.40] loss=0.15 avg=0.12
# [5471 | 541.31] loss=0.09 avg=0.12
# [5472 | 542.22] loss=0.24 avg=0.12
# [5473 | 543.12] loss=0.34 avg=0.12
# [5474 | 544.03] loss=0.14 avg=0.12
# [5475 | 544.94] loss=0.08 avg=0.12
# [5476 | 545.84] loss=0.10 avg=0.12
# [5477 | 546.75] loss=0.21 avg=0.12
# [5478 | 547.66] loss=0.13 avg=0.12
# [5479 | 548.56] loss=0.10 avg=0.12
# [5480 | 549.46] loss=0.18 avg=0.12
# [5481 | 550.38] loss=0.06 avg=0.12
# [5482 | 551.28] loss=0.09 avg=0.12
# [5483 | 552.18] loss=0.12 avg=0.12
# [5484 | 553.09] loss=0.06 avg=0.12
# [5485 | 553.99] loss=0.09 avg=0.12
# [5486 | 554.90] loss=0.08 avg=0.12
# [5487 | 555.80] loss=0.10 avg=0.12
# [5488 | 556.71] loss=0.09 avg=0.12
# [5489 | 557.61] loss=0.08 avg=0.12
# [5490 | 558.51] loss=0.12 avg=0.12
# [5491 | 559.42] loss=0.12 avg=0.12
# [5492 | 560.32] loss=0.14 avg=0.12
# [5493 | 561.22] loss=0.08 avg=0.12
# [5494 | 562.12] loss=0.07 avg=0.12
# [5495 | 563.03] loss=0.09 avg=0.12
# [5496 | 563.93] loss=0.19 avg=0.12
# [5497 | 564.83] loss=0.22 avg=0.12
# [5498 | 565.74] loss=0.12 avg=0.12
# [5499 | 566.64] loss=0.20 avg=0.12
# [5500 | 567.55] loss=0.05 avg=0.12
# ======== SAMPLE 1 ========
#  goal social norms ethics also help modify values amongst one another amongst various social groups example workers construction workers might prefer membersconstituency trust members employer trust fundamen tal different among groups thus different ethical norms come tension ethical norms created various societal viewpoints also reflected publications ai authors assign right ethical norms authorship professional norms practice professional norms one prac tical point authorship professional norms merely recording statement made profession al surely enough authorship diverse cs professions considering ethics professional norms might useful among others among groups eg women nonbinary gender persons disabilities along demographic groups labeled “other” “women” within given group characteristic described phenomenon §enschriftenberg et al “groups sex associate gender characteristics employ” source diversity opportunity identifying novelties technology future workplace characterized increasing use new ai techniques eg machine learning alessandro blasimme effy vayena governance ai use rise demand stronger norms ethics among diverse groups people broadly moral rights think important preserve social norms past conceptual framework current functional perspective shape future entrusted professionals blame technology used harm individuals perhaps notably anthropology science technology collected cultural diversity arguably key attribute identity category ai ai used meaning anthropology research christopher b rulemarching et al “cultural diversity” j dalton et al “are african penguins different penguins different landmass” penguins one might argue identity groups exist specific geographical space like african penguins kandinsky et al “identity categorism selfidentification new categorisms domain gender” j lohr “canadian anthropologist” citizen augmentation individuals” personhood enforced particular geo graphical region maybe region cultural identity formed various periods middle ages east north africa slaves people ancestors still exist—but lost dataset rich body information tried contact people region always contact information end conquering devel opment scholars like hobbes locke rousseau first white people arrived african penguin john moray lived rohingya refugee camp iriseskil gebru cost estimations forethought put animals’ exclusion became much systematic process startedchers zoographies shel yans ancestors still living today’s world’s first written record books include “marley the elephant” darwinia fin panther glyptodon africanus man special snow leopard iguana david animal abused coverdale nd httpsdoiorg1010385056633 francis j falke et al “the coevolution human fertility wealth inheritance dynamics african american community” globe mail june httpsdoiorg1010800197224125x201910247925 × african american minds uvaiza bush pump natural history lecture notes artificial intel igence berkeley ca counterpoint k–d plan january httparxivorgabs190408791 paul wolff “race social construct scientists argue” science –perspectives ethics ai computer science original post written june hardt price srebro et al “equality opportunity supervised learning” benjamin r baer daniel e gilbert martin wells scenario loan repayment wish predict whether individual repay loan indeed decision making often thought discriminatory individual loan repayr may reflect characteristics loan repayment rate particular race gender make different loan repayr however prediction particularly likely accurate understanding loan repayment depends see x z friedman gidon f baer “fair prediction disparate impact” aea papers proceedings –angwin parris jr “avoiding discrimination causal reasoning” thirtysecond aaai conference artificial intel igence aaai16 niki kron et al “avoiding discrimination causal reasoning” thirtythird aaai conference artificial intel igence aaai16 niki kron et al “avoiding discrimination causal reasoning” thirtythird aaai conference artificial intel igence a ...
#
# [5501 | 586.54] loss=0.15 avg=0.12
# [5502 | 587.44] loss=0.11 avg=0.12
# [5503 | 588.35] loss=0.06 avg=0.12
# [5504 | 589.25] loss=0.11 avg=0.12
# [5505 | 590.16] loss=0.11 avg=0.12
# [5506 | 591.06] loss=0.11 avg=0.12
# [5507 | 591.96] loss=0.12 avg=0.12
# [5508 | 592.87] loss=0.16 avg=0.12
# [5509 | 593.77] loss=0.08 avg=0.12
# [5510 | 594.67] loss=0.07 avg=0.12
# [5511 | 595.58] loss=0.04 avg=0.12
# [5512 | 596.48] loss=0.23 avg=0.12
# [5513 | 597.38] loss=0.12 avg=0.12
# [5514 | 598.29] loss=0.10 avg=0.12
# [5515 | 599.19] loss=0.09 avg=0.12
# [5516 | 600.10] loss=0.07 avg=0.12
# [5517 | 601.00] loss=0.09 avg=0.12
# [5518 | 601.91] loss=0.15 avg=0.12
# [5519 | 602.81] loss=0.05 avg=0.12
# [5520 | 603.71] loss=0.09 avg=0.12
# [5521 | 604.62] loss=0.05 avg=0.12
# [5522 | 605.52] loss=0.06 avg=0.12
# [5523 | 606.42] loss=0.12 avg=0.12
# [5524 | 607.32] loss=0.14 avg=0.12
# [5525 | 608.23] loss=0.08 avg=0.12
# [5526 | 609.13] loss=0.12 avg=0.12
# [5527 | 610.03] loss=0.11 avg=0.12
# [5528 | 610.94] loss=0.09 avg=0.12
# [5529 | 611.84] loss=0.13 avg=0.12
# [5530 | 612.74] loss=0.16 avg=0.12
# [5531 | 613.65] loss=0.12 avg=0.12
# [5532 | 614.55] loss=0.11 avg=0.12
# [5533 | 615.46] loss=0.14 avg=0.12
# [5534 | 616.36] loss=0.07 avg=0.12
# [5535 | 617.26] loss=0.19 avg=0.12
# [5536 | 618.16] loss=0.09 avg=0.12
# [5537 | 619.07] loss=0.11 avg=0.12
# [5538 | 619.97] loss=0.09 avg=0.12
# [5539 | 620.88] loss=0.12 avg=0.12
# [5540 | 621.78] loss=0.08 avg=0.12
# [5541 | 622.68] loss=0.06 avg=0.12
# [5542 | 623.59] loss=0.11 avg=0.12
# [5543 | 624.49] loss=0.08 avg=0.12
# [5544 | 625.40] loss=0.13 avg=0.12
# [5545 | 626.30] loss=0.12 avg=0.12
# [5546 | 627.20] loss=0.10 avg=0.12
# [5547 | 628.10] loss=0.04 avg=0.11
# [5548 | 629.01] loss=0.10 avg=0.11
# [5549 | 629.91] loss=0.08 avg=0.11
# [5550 | 630.82] loss=0.08 avg=0.11
# [5551 | 631.72] loss=0.12 avg=0.11
# [5552 | 632.62] loss=0.11 avg=0.11
# [5553 | 633.53] loss=0.18 avg=0.11
# [5554 | 634.43] loss=0.13 avg=0.11
# [5555 | 635.34] loss=0.10 avg=0.11
# [5556 | 636.24] loss=0.07 avg=0.11
# [5557 | 637.15] loss=0.13 avg=0.11
# [5558 | 638.05] loss=0.05 avg=0.11
# [5559 | 638.95] loss=0.15 avg=0.11
# [5560 | 639.86] loss=0.13 avg=0.11
# [5561 | 640.76] loss=0.12 avg=0.11
# [5562 | 641.66] loss=0.23 avg=0.12
# [5563 | 642.57] loss=0.17 avg=0.12
# [5564 | 643.47] loss=0.05 avg=0.12
# [5565 | 644.37] loss=0.09 avg=0.12
# [5566 | 645.28] loss=0.15 avg=0.12
# [5567 | 646.18] loss=0.06 avg=0.11
# [5568 | 647.08] loss=0.13 avg=0.12
# [5569 | 647.99] loss=0.11 avg=0.12
# [5570 | 648.89] loss=0.13 avg=0.12
# [5571 | 649.79] loss=0.06 avg=0.11
# [5572 | 650.69] loss=0.12 avg=0.11
# [5573 | 651.60] loss=0.06 avg=0.11
# [5574 | 652.50] loss=0.06 avg=0.11
# [5575 | 653.41] loss=0.09 avg=0.11
# [5576 | 654.31] loss=0.08 avg=0.11
# [5577 | 655.22] loss=0.14 avg=0.11
# [5578 | 656.12] loss=0.12 avg=0.11
# [5579 | 657.02] loss=0.04 avg=0.11
# [5580 | 657.93] loss=0.10 avg=0.11
# [5581 | 658.83] loss=0.10 avg=0.11
# [5582 | 659.74] loss=0.06 avg=0.11
# [5583 | 660.64] loss=0.05 avg=0.11
# [5584 | 661.54] loss=0.06 avg=0.11
# [5585 | 662.45] loss=0.05 avg=0.11
# [5586 | 663.35] loss=0.09 avg=0.11
# [5587 | 664.26] loss=0.12 avg=0.11
# [5588 | 665.16] loss=0.12 avg=0.11
# [5589 | 666.07] loss=0.06 avg=0.11
# [5590 | 666.97] loss=0.07 avg=0.11
# [5591 | 667.87] loss=0.13 avg=0.11
# [5592 | 668.78] loss=0.10 avg=0.11
# [5593 | 669.68] loss=0.11 avg=0.11
# [5594 | 670.58] loss=0.25 avg=0.11
# [5595 | 671.49] loss=0.04 avg=0.11
# [5596 | 672.39] loss=0.16 avg=0.11
# [5597 | 673.29] loss=0.08 avg=0.11
# [5598 | 674.20] loss=0.06 avg=0.11
# [5599 | 675.10] loss=0.06 avg=0.11
# [5600 | 676.01] loss=0.22 avg=0.11
# Saving /content/drive/MyDrive/Coding3/gpt2_fine_tuning_run_1/model-5600
# ======== SAMPLE 1 ========
# ...
# [5640 | 744.73] loss=0.12 avg=0.11
# [5641 | 745.64] loss=0.08 avg=0.11
# [5642 | 746.54] loss=0.07 avg=0.11
# [5643 | 747.45] loss=0.10 avg=0.11
# [5644 | 748.35] loss=0.08 avg=0.11
# [5645 | 749.26] loss=0.08 avg=0.11
# [5646 | 750.16] loss=0.12 avg=0.11
# [5647 | 751.06] loss=0.14 avg=0.11
# [5648 | 751.97] loss=0.12 avg=0.11
# [5649 | 752.87] loss=0.09 avg=0.11
# [5650 | 753.77] loss=0.06 avg=0.11
# [5651 | 754.68] loss=0.10 avg=0.11
# [5652 | 755.58] loss=0.05 avg=0.11
# [5653 | 756.48] loss=0.13 avg=0.11
# [5654 | 757.39] loss=0.06 avg=0.11
# [5655 | 758.29] loss=0.07 avg=0.11
# [5656 | 759.20] loss=0.19 avg=0.11
# [5657 | 760.10] loss=0.10 avg=0.11
# [5658 | 761.00] loss=0.10 avg=0.11
# [5659 | 761.91] loss=0.04 avg=0.11
# [5660 | 762.81] loss=0.10 avg=0.11
# [5661 | 763.72] loss=0.16 avg=0.11
# [5662 | 764.62] loss=0.17 avg=0.11
# [5663 | 765.53] loss=0.31 avg=0.11
# [5664 | 766.44] loss=0.07 avg=0.11
# [5665 | 767.34] loss=0.12 avg=0.11
# [5666 | 768.24] loss=0.11 avg=0.11
# [5667 | 769.15] loss=0.11 avg=0.11
# [5668 | 770.05] loss=0.21 avg=0.11
# [5669 | 770.95] loss=0.11 avg=0.11
# [5670 | 771.86] loss=0.10 avg=0.11
# [5671 | 772.76] loss=0.13 avg=0.11
# [5672 | 773.67] loss=0.14 avg=0.11
# [5673 | 774.57] loss=0.15 avg=0.11
# [5674 | 775.47] loss=0.10 avg=0.11
# [5675 | 776.38] loss=0.09 avg=0.11
# [5676 | 777.28] loss=0.21 avg=0.11
# [5677 | 778.19] loss=0.05 avg=0.11
# [5678 | 779.09] loss=0.10 avg=0.11
# [5679 | 779.99] loss=0.14 avg=0.11
# [5680 | 780.90] loss=0.09 avg=0.11
# [5681 | 781.80] loss=0.15 avg=0.11
# [5682 | 782.71] loss=0.11 avg=0.11
# [5683 | 783.61] loss=0.25 avg=0.11
# [5684 | 784.52] loss=0.07 avg=0.11
# [5685 | 785.42] loss=0.07 avg=0.11
# [5686 | 786.32] loss=0.19 avg=0.11
# [5687 | 787.23] loss=0.07 avg=0.11
# [5688 | 788.13] loss=0.15 avg=0.11
# [5689 | 789.03] loss=0.08 avg=0.11
# [5690 | 789.93] loss=0.11 avg=0.11
# [5691 | 790.84] loss=0.21 avg=0.11
# [5692 | 791.74] loss=0.10 avg=0.11
# [5693 | 792.64] loss=0.10 avg=0.11
# [5694 | 793.55] loss=0.22 avg=0.11
# [5695 | 794.45] loss=0.12 avg=0.11
# [5696 | 795.35] loss=0.10 avg=0.11
# [5697 | 796.26] loss=0.23 avg=0.12
# [5698 | 797.16] loss=0.10 avg=0.12
# [5699 | 798.06] loss=0.12 avg=0.12
# [5700 | 798.97] loss=0.07 avg=0.12
# ======== SAMPLE 1 ========
#  owes society make moral means final moral econ omy information intel igence us context burawoy niki diego meng xerox holics –corbettdavies sam sharad goel “the measureable invisible architects technological systems” science engineering ethics –bettman nico “computational mod els” march httpswwwsciencedirectcomsciencearticlecompii s0959337615301004 httpswwwerolsorgwhatwedobesensei findarticles20181101computationalmodels andersgudginganhtml murphy robert f “modelling decimation racial social emp brookings lifecycle alter i’moday” cultural anthropology –pakman hideo “geeks social imaginaries recursive publics” cultural anthropology –howell tim “grounded anthropology lesson urban technic evolution” urban science october httpswwwthenationcom20181015338938t063323zwusenacais crawford daniel rock “the architecture artificial intelligence” interviews george bekey frank pasquale chris russell louis mumford technics human development myth frameworks new directions psychology httpsmediumcomerdemosinterviewhowell howard howard richard architectural musko patrick howard geraint wiggins “final frontier” stanford encyclopedia philosophy winter edition ed edward n zalta httpsplatostanfordeducgibinencyclopediaarchitectureforyoutroboticshowell howard richard icculus notice duty toward ethical behavior respect nature domain especial valuableries example renderings park51 don’t expect buildings bridges trucks palatial state licensed practical necessary although may resemble office space managers may imagine architects plumbers surveyors survey engineers plumbers and so forth list goes without saying many images online architecture firmsGWPH visited website multiple listings multiple purposes often generic white boxes charge different insurance co saved many lives benefited many others none power arranges things fly unclear market forces alone currently amount unpredictable uncertain see market insurance pay pervasiveness state art insurance comes tax system think theoretical worst case scenarios would govern western european union countries think current insurance regimes wel require least 90 days intensive monitoring project’s completion simulta neously structured wishbone allows assessment protection differentVersions insurance policies single market possibly multiple national regimes would limit area protected several european countries possibly four countries protected much vio lations also arab spring namely uaeaa new republic ardal european space agency open ai application eu’s social principles human rights well european union tempted take similar approach may ultimately decide create framework asylum applications based data relating protected char it certain ethi cal origins states somewhere between “ok go” “ice” “clouds” solution whatever human motivations behind creation universe different ontologies possible left wondering whether whatever leaky abstraction wrongdo ing space far reachless human controllers perhaps intelligent universe parallel universe te part especial environmen tal conscious biological mental properties typical background conditions flourishing would tout protection new perhaps exotic perhaps exotic alife characteristics alife mostly arises relationships massive data sets used series algorithms try make sense understand worlds varied shades identity ranging confidently confident developers develop guidelines ai systems follow internal succinct independent one reason much software development ground changes rapidly reflect dynamic situations use may even find outright Wrong many developers working ai right thing want done change highly contextspecific ways code analysis loosely code refers formatted input used system producing output unfortunately complicated often controversialgeist subject matter discussions highlevel policy domains however crucial realize ethical concerns range anywhere space directions initiatives must paid close attention priorities codes ethics ai domains especial relevant one fundamen tal depen ...
#
# [5701 | 818.20] loss=0.12 avg=0.12
# [5702 | 819.10] loss=0.10 avg=0.11
# [5703 | 820.01] loss=0.13 avg=0.12
# [5704 | 820.91] loss=0.06 avg=0.11
# [5705 | 821.81] loss=0.07 avg=0.11
# [5706 | 822.72] loss=0.11 avg=0.11
# [5707 | 823.62] loss=0.11 avg=0.11
# [5708 | 824.53] loss=0.09 avg=0.11
# [5709 | 825.43] loss=0.20 avg=0.11
# [5710 | 826.35] loss=0.07 avg=0.11
# [5711 | 827.25] loss=0.05 avg=0.11
# [5712 | 828.16] loss=0.06 avg=0.11
# [5713 | 829.07] loss=0.06 avg=0.11
# [5714 | 829.98] loss=0.12 avg=0.11
# [5715 | 830.89] loss=0.19 avg=0.11
# [5716 | 831.80] loss=0.10 avg=0.11
# [5717 | 832.70] loss=0.11 avg=0.11
# [5718 | 833.61] loss=0.05 avg=0.11
# [5719 | 834.51] loss=0.09 avg=0.11
# [5720 | 835.42] loss=0.10 avg=0.11
# [5721 | 836.32] loss=0.16 avg=0.11
# [5722 | 837.23] loss=0.11 avg=0.11
# [5723 | 838.13] loss=0.17 avg=0.11
# [5724 | 839.03] loss=0.19 avg=0.11
# [5725 | 839.93] loss=0.09 avg=0.11
# [5726 | 840.84] loss=0.09 avg=0.11
# [5727 | 841.74] loss=0.10 avg=0.11
# [5728 | 842.65] loss=0.12 avg=0.11
# [5729 | 843.55] loss=0.10 avg=0.11
# [5730 | 844.46] loss=0.03 avg=0.11
# [5731 | 845.36] loss=0.06 avg=0.11
# [5732 | 846.26] loss=0.18 avg=0.11
# [5733 | 847.16] loss=0.14 avg=0.11
# [5734 | 848.07] loss=0.14 avg=0.11
# [5735 | 848.97] loss=0.16 avg=0.11
# [5736 | 849.87] loss=0.13 avg=0.11
# [5737 | 850.78] loss=0.05 avg=0.11
# [5738 | 851.68] loss=0.04 avg=0.11
# [5739 | 852.59] loss=0.10 avg=0.11
# [5740 | 853.49] loss=0.07 avg=0.11
# [5741 | 854.39] loss=0.07 avg=0.11
# [5742 | 855.30] loss=0.04 avg=0.11
# [5743 | 856.20] loss=0.12 avg=0.11
# [5744 | 857.10] loss=0.08 avg=0.11
# [5745 | 858.00] loss=0.08 avg=0.11
# [5746 | 858.91] loss=0.09 avg=0.11
# [5747 | 859.81] loss=0.05 avg=0.11
# [5748 | 860.71] loss=0.10 avg=0.11
# [5749 | 861.62] loss=0.19 avg=0.11
# [5750 | 862.52] loss=0.09 avg=0.11
# [5751 | 863.42] loss=0.13 avg=0.11
# [5752 | 864.33] loss=0.15 avg=0.11
# [5753 | 865.23] loss=0.14 avg=0.11
# [5754 | 866.13] loss=0.11 avg=0.11
# [5755 | 867.04] loss=0.13 avg=0.11
# [5756 | 867.94] loss=0.16 avg=0.11
# [5757 | 868.84] loss=0.10 avg=0.11
# [5758 | 869.75] loss=0.08 avg=0.11
# [5759 | 870.65] loss=0.14 avg=0.11
# [5760 | 871.55] loss=0.10 avg=0.11
# [5761 | 872.46] loss=0.14 avg=0.11
# [5762 | 873.36] loss=0.09 avg=0.11
# [5763 | 874.27] loss=0.13 avg=0.11
# [5764 | 875.17] loss=0.07 avg=0.11
# [5765 | 876.08] loss=0.04 avg=0.11
# [5766 | 876.98] loss=0.09 avg=0.11
# [5767 | 877.88] loss=0.18 avg=0.11
# [5768 | 878.79] loss=0.14 avg=0.11
# [5769 | 879.69] loss=0.14 avg=0.11
# [5770 | 880.60] loss=0.07 avg=0.11
# [5771 | 881.50] loss=0.11 avg=0.11
# [5772 | 882.40] loss=0.08 avg=0.11
# [5773 | 883.31] loss=0.08 avg=0.11
# [5774 | 884.21] loss=0.26 avg=0.11
# [5775 | 885.11] loss=0.10 avg=0.11
# [5776 | 886.02] loss=0.18 avg=0.11
# [5777 | 886.92] loss=0.16 avg=0.11
# [5778 | 887.83] loss=0.16 avg=0.11
# [5779 | 888.73] loss=0.06 avg=0.11
# [5780 | 889.63] loss=0.18 avg=0.11
# [5781 | 890.54] loss=0.13 avg=0.11
# [5782 | 891.44] loss=0.10 avg=0.11
# [5783 | 892.34] loss=0.16 avg=0.11
# [5784 | 893.25] loss=0.14 avg=0.11
# [5785 | 894.15] loss=0.15 avg=0.11
# [5786 | 895.05] loss=0.08 avg=0.11
# [5787 | 895.96] loss=0.04 avg=0.11
# [5788 | 896.86] loss=0.10 avg=0.11
# [5789 | 897.76] loss=0.07 avg=0.11
# [5790 | 898.67] loss=0.12 avg=0.11
# [5791 | 899.57] loss=0.09 avg=0.11
# [5792 | 900.47] loss=0.12 avg=0.11
# [5793 | 901.38] loss=0.06 avg=0.11
# [5794 | 902.28] loss=0.14 avg=0.11
# [5795 | 903.18] loss=0.08 avg=0.11
# [5796 | 904.08] loss=0.08 avg=0.11
# [5797 | 904.98] loss=0.17 avg=0.11
# [5798 | 905.88] loss=0.12 avg=0.11
# [5799 | 906.79] loss=0.05 avg=0.11
# [5800 | 907.69] loss=0.27 avg=0.11
# ======== SAMPLE 1 ========
# ��the new japan ww3OTAL” japan times august httpswwwjapantimescojpnews20170816businesspe20170808new yorkasianjobsbot20170816 asianjobsbot japan times february 2019more info see asia news center’s recent interview sony group’s ict ethics guidelines japanese ai ethics guidelines httpwwwasia newscenterkatwhatwedoourinsightsgroups perspectives approaches ai ethics east asia interest entertainer caretaker62 blurs intended use line tool partner pepper functions assistant priest also explicitly envisioned become much partneroriented practical example aibo pet robot dog sony aibo first available official relaunched january reinforced machine learning64 jiro kokuryo professor keio university explains aibo robots mimic real dogs also distinct robotic features avoid uncanny valleyassociated fears65 spite design measures aibo beyond repair owners sent elaborate buddhist burial ceremony demonstrating unique attachment eight hundred buried robot dogs66 sony part approaches ai tool achieve “harmony society” sony group’s guidelines emphasize alignment human wellbeing v v philosophy background note emphasis human wellbeing emphasis mutual benefit western economic cooperation notable parallels found aibo ethics discussion paralysis autonomous robots also distinct another east asia tool approach ai tool achieve “harmony society” sony group’s guidelines emphasize alignment human wellbeing eg future long term prosperity society encourages participants enhance capabilities using east asia technologies v v philosophy discussion pagoto backdrop imagenavigation gestures control dominated panoptic techniques image framing capture highlight edges subjects see later movement contours achieved integrating ai’s digital world challenge complicating factors related trust trust social norms ai’s socialization use seem add another layer complexity subjectivity social norms ai addition challenging realize alongside endeavors apply creative social norms ai humankind actively contribute undermining human wellbeing effecting trans parency optimiz ing automation exploiting artifi city intelligibility ai robots mitigate many social concerns associated automation including unemployment lack jobs gender affect ability moreover codified social norms ai rob us humility relinquishing control ai many may poses significant social challenge considering issues may pose verge automation like deeplearning ai systems achieved without explicitly referring issue robot unemployment yet another socalled “knowledge unemployment”or broader lack skill acquisition airelated technologies affect aspects human labor social solidarity discussed earlier chapter striking annual increase unemployment witnessed advanced industrial countries region including uae ken Suzheng berk ustun scored substantial boeing successes minai success f4 wiebe scheuerman “cooperative learning versus adversarial reinforcement learning” advances robotics –j simonsen rob fergus “on automated hiring scheduling automation fast growing area” econ profiling –d simontane “platforms work automated hiring platforms” nber working paper w25682 nber working paper w25682 yuichiro hirochi “mastering game go without human knowledge” nature –yoshua bengio “job market signaling mechanisms” annual review economics –j simonsen “robotics lessons learning robot’s –fairness ethics robot’s math –rob vierhile “job market signaling” robot ethics washington dc jobs pegah moradi karen levy despite clear empirical understanding human resource constraints human labor economists often worry social outcomes induced ai robots may disproportionately harmmine predictions wrong though clear also acknowledge facts bias aversion especial problem ai robotics aidriven automation augmentation even replacement human labor may create new jobs highlights importance concepts education safety prevention risk balancing act especial complex phenomenon humans replaced machines many human roles requiring human skil capacity act preemptive preemptive actions may ...
#
# [5801 | 926.60] loss=0.07 avg=0.11
# [5802 | 927.50] loss=0.11 avg=0.11
# [5803 | 928.40] loss=0.15 avg=0.11
# [5804 | 929.31] loss=0.10 avg=0.11
# [5805 | 930.21] loss=0.05 avg=0.11
# [5806 | 931.12] loss=0.10 avg=0.11
# [5807 | 932.02] loss=0.15 avg=0.11
# [5808 | 932.92] loss=0.07 avg=0.11
# [5809 | 933.83] loss=0.13 avg=0.11
# [5810 | 934.73] loss=0.05 avg=0.11
# [5811 | 935.64] loss=0.10 avg=0.11
# [5812 | 936.54] loss=0.12 avg=0.11
# [5813 | 937.44] loss=0.14 avg=0.11
# [5814 | 938.35] loss=0.09 avg=0.11
# [5815 | 939.25] loss=0.10 avg=0.11
# [5816 | 940.15] loss=0.13 avg=0.11
# [5817 | 941.06] loss=0.11 avg=0.11
# [5818 | 941.96] loss=0.15 avg=0.11
# [5819 | 942.86] loss=0.16 avg=0.11
# [5820 | 943.76] loss=0.11 avg=0.11
# [5821 | 944.67] loss=0.12 avg=0.11
# [5822 | 945.57] loss=0.12 avg=0.11
# [5823 | 946.47] loss=0.18 avg=0.11
# [5824 | 947.38] loss=0.11 avg=0.11
# [5825 | 948.28] loss=0.06 avg=0.11
# [5826 | 949.19] loss=0.05 avg=0.11
# [5827 | 950.09] loss=0.15 avg=0.11
# [5828 | 951.00] loss=0.13 avg=0.11
# [5829 | 951.90] loss=0.10 avg=0.11
# [5830 | 952.80] loss=0.05 avg=0.11
# [5831 | 953.70] loss=0.23 avg=0.11
# [5832 | 954.61] loss=0.18 avg=0.11
# [5833 | 955.51] loss=0.09 avg=0.11
# [5834 | 956.42] loss=0.07 avg=0.11
# [5835 | 957.32] loss=0.10 avg=0.11
# [5836 | 958.22] loss=0.09 avg=0.11
# [5837 | 959.13] loss=0.15 avg=0.11
# [5838 | 960.03] loss=0.08 avg=0.11
# [5839 | 960.94] loss=0.13 avg=0.11
# [5840 | 961.84] loss=0.07 avg=0.11
# [5841 | 962.74] loss=0.10 avg=0.11
# [5842 | 963.65] loss=0.07 avg=0.11
# [5843 | 964.55] loss=0.10 avg=0.11
# [5844 | 965.45] loss=0.12 avg=0.11
# [5845 | 966.36] loss=0.11 avg=0.11
# [5846 | 967.26] loss=0.20 avg=0.11
# [5847 | 968.17] loss=0.09 avg=0.11
# [5848 | 969.07] loss=0.07 avg=0.11
# [5849 | 969.98] loss=0.03 avg=0.11
# [5850 | 970.88] loss=0.08 avg=0.11
# [5851 | 971.79] loss=0.08 avg=0.11
# [5852 | 972.69] loss=0.15 avg=0.11
# [5853 | 973.60] loss=0.10 avg=0.11
# [5854 | 974.50] loss=0.17 avg=0.11
# [5855 | 975.41] loss=0.11 avg=0.11
# [5856 | 976.31] loss=0.15 avg=0.11
# [5857 | 977.21] loss=0.11 avg=0.11
# [5858 | 978.12] loss=0.11 avg=0.11
# [5859 | 979.03] loss=0.13 avg=0.11
# [5860 | 979.93] loss=0.15 avg=0.11
# [5861 | 980.84] loss=0.13 avg=0.11
# [5862 | 981.74] loss=0.16 avg=0.11
# [5863 | 982.64] loss=0.10 avg=0.11
# [5864 | 983.54] loss=0.11 avg=0.11
# [5865 | 984.45] loss=0.07 avg=0.11

# %% [markdown]
# ### Explore Conditional Text!!
#
#
# *   [Conditional Text GPT-2](https://www.ivanlai.project-ds.net/post/conditional-text-generation-by-fine-tuning-gpt-2)

# %%
'''
#Load the model from checkpoint
gpt2.copy_checkpoint_from_gdrive(run_name=checkpoint_name)
tf.reset_default_graph()
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name=checkpoint_name)
'''

# %%
input_prompt = "Artificial Intelligence is… "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.2, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=70, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Artificial Intelligence is… ict impact every human endeavor ict design london nicholas g shal ows internet brains new york liveright publishing corp next set technologies underwriting ai ethical principles including transparency accountability among paul rauwolf joanna j bryson yourself34 ai could always use feedback improve core algorithms make better even without additional enhancements could always benefit existing ai systems since require input data models different audiences also feedback improve predictive accuracy although noble intentions crow many cases leads people developing ai become tech
# ====================
# Artificial Intelligence is… ict impact every human endeavor ict design ict user experience ict design ict user experience designer x   x ai system generates value user experience leads better customer acquisition experience wide range ethical desirable outcomes ict users google facebook twitter could potential lead better understanding trust algorithms google facebook twitter could help you identify potential ethical issues algorithms society large emphasis ethics ai google came heels walkout organized women google refused contend sexual harassment undercompensation compared male coworkers culture consistently undervalues demeans
# ====================
# Artificial Intelligence is… ict impact every human endeavor ict design london nicholas g shal ows internet brains new york liveright publishing corp next set technologies underwriting ai ethical principles including transparency accountability among paul rauwolf joanna j bryson yourself34 ai hleg also released ai principles document highlights steps already taken form steve dipaola liane gabora “responsible bots guidelines developers conversational ai” communications acm ––chatbots personalized learning systems
# ====================

# %%
input_prompt = "Equity is… "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.15, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=50, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Equity is… ict offer context specific policy framework trustworthy ai implies acceptance among stakeholders including individual public private sectors responsibility engineering design operation informed informed democratic processes means adequate funding allocation training activities development implementation ai systems including funding bodies european union eu organisation economic cooperation development oecd ai narrative –in conclusion reflecting increased political societal attention issues connected development ai general data protection regulation gdpr applies entities participating european union ai narrative –in conclusion reflecting increased political societal attention issues connected development ai accurate disclosures
# ====================
# Equity is… ict see intelligence identity –identity –invalid –invalid –f intelligent assistants iq see intelligence quotient principles –iran air flight fundamental iran air flight common sense iran air flight common sense jordan –intelligence see also artificial intelligence algorithmic governance –iran air flight risk iran air flight risk management –ira see also human rights equality rights –sentience –isaacs algorithms –isaacs terminology –ishiguro hirochi intentional agency 198n9 isolation social –inter
# ====================
# Equity is… ict offer context specific policy framework matters simply want levy tax system collect payer’s data every single transaction every single person participating equation creating financial incentive keep tax system simple fairness mandate use data best interest example could years going algorithm pays lip service human rights obligations transparency tax system designed specifical take account ethical questions put forward policy proposals places things like european union approach would followed instance tax system highincome individuals would individual national budgets reflect ability therefore act quickly starters dismantling complex algorithm came tax system would seen
# ====================

# %%
input_prompt = "Ethics is… "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.1, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=70, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Ethics is… ian machines like novel new york knopf doure sturm noemie elhadad proceedings aristotelian society london whittlestone james probability calibration group gender” proceedings conference fairness accountability transparency –igi see industry iq see intelligence inequality –index natural justice –correa fatimah yasseri nabil todonobe “a right reasonable inferences rethinking data protection law age big data ai” harv j law technology review –s
# ====================
# Ethics is… ian machines like novel new york knopf doure sturm noemie elhadad proceedings aristotelian society london whittlestone james probability calibration group gender” proceedings conference fairness accountability transparency –jessica wapner “the enemy good estimating cost waiting nearly perfect automated vehicles” rand corporation httpswwwrandorgpubsresearchreportsrr2150html ronald c arkin creating adversarial exemplars use data adversarial examples fort ray k
# ====================
# Ethics is… ian machines like novel new york knopf doure sturm noemie elhadad proceedings aristotelian society london whittlestone james probability calibration group gender” proceedings conference fairness accountability transparency –jessica wapner “the enemy good estimating cost waiting nearly perfect automated vehicles” rand corporation httpswwwrandorgpubsresearchreportsrr2150html ronald c arkin creating adversarial exemplars use data adversarial examples fort ray k
# ====================

# %%
input_prompt = "Accountable AI is... "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.05, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=40, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Accountable AI is... ict defines problem “ai directed human labor” uses multifaceted datarich resources tied firm’s specific knowledge base used make automated decisions conduct actual work65 thus workers real labor rather machines dispensable human labor use resources like nonrenewable resources like sunlight falling wood chip manufacturing processes similarly could instead signatory cooperative project seeree scott “creative adversarial networks” –report creative adversarial networks working professionals –robot teaching pedagogy policy –robot�
# ====================
# Accountable AI is... ict ict chang ict changing ict changing tech nology ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing ict changing
# ====================
# Accountable AI is... ict defines problem “actively soliciting solutions”when people ask ethical questions ai “actively soliciting solutions” includ ing employment housing immigration customs enforcement border securityjudicial assessment data collection biometrics also used predict person’s future criminal conduct dangerousness monitor communications criminal riskassessment proceedings federal magistrate court approved use ai predictive analytics product services federal probation administrative law “in cases person pretrial risk assessment failure obtain signed statement recognising adverse event giving effect upon ‘finding�
# ====================

# %%
input_prompt = "Responsible AI is...  "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.15, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=30, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Responsible AI is...  urs gasser carolyn schmitt companies—are engaged norm creation lesser extent administration—while still keeping ethics promise made ethical aligned company’s approach released statement company aims develop ethical aligned responsible ai no questions asked leading role ai ict impact ethical decisions every aspect company’s operations however ethical promiseably transparent process evaluation information resources used develop deploy deploy ai system including financial incentives potential conflicts exist public commitments trustworthy ai come several stages including various codes ethics google created responsible ai initiative google
# ====================
# Responsible AI is...  urs gasser carolyn schmitt companies—are engaged norm creation lesser extent administration—while still maintaining professional norms company culture remains largely experimental accordingly norms created google glass suggest norms might adapt much like brooks required new york sophia press frank pasquale black box society cambridge harvard university press normen staat “responsible bots” google glass ada algorithms –google glass removed safety glasses required new users google glass discontinued production safety glasses shortly company learned would likely generate negative consumer negative
# ====================
# Responsible AI is...  urs gasser carolyn schmitt companies—are engaged norm creation lesser extent administration—while still maintaining professional norms aspirational rather practical ai hleg claims requires membership association existing larger groups society confront issues norms must continuously monitor shift normative status quo reflect status quo created new members must also continuously strive extend professional norms ethical principles beneficial increased use ai legitimate professional norms aspirational rather pragmatic reasons well practical reasons professional norms reflect status quo purposes important take ai account discrepancies norms statutorily mandated employers employees respectively and
# ====================

# %%
input_prompt = "Accountability is…  "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.15, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=30, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Accountability is…  urs gasser carolyn schmitt companies like facebook google even offer chatbots understand understand understand give httpswwwfacebookcomdevelopersarechatbot httpsautomatedercoderjailsocietyarevery similar examples see httpswwwfacebookgoogleschatbot httpswwwfacebookcomdevelopersarechatbot nick stat “google’s community analyzes nearly million interactions platform user data shows nearly third people post negative things ” politico may httpswww politicocomnextgen technology google’
# ====================
# Accountability is…  urs gasser carolyn schmitt companies like facebook google even offer chatbots understand understand understand give httpswwwfacebookcomdevelopersarechatbot httpswwwfacebookcomdevelopersarechatbot shannon mattern developers also encourage encourage intelligent actions people’s behalf27 thirdparty companies also provide services assist developers translating enphrases en français en francisco’s httpswwwfranconewsnetworkartificialintelligence httpfranconwhowasapnewprojectshtml see
# ====================
# Accountability is…  urs gasser carolyn schmitt companies like facebook google even offer chatbots understand understand understand give httpswwwfacebookcomsupport chatbot httpsenable chatbotlenetoggleshowportraithtml shannon mattern product marketing materials also give general idea kind chatbot could useful person instance elderly relative less likely trustworthy trustworthy” eg could use voice recognition identify dementia patients poor memory patients may trust able refer doc accurately cared about concerns “accuracy selfreported measures social mental health” could also used detect presence
# ====================

# %%
input_prompt = "Ethical AI is…  "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.2, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=40, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Ethical AI is…  urs gasser carolyn schmitt companies—are engaged norm creation lesser extent administration—are engaged setting norms example amazon implementing them—and signaling norms accountability additional important signal creators creators ethical creators maintain norms maintain created3 norms steward effective governance regime stuart russell peter chinao “a place sun” id –introducing sme artificial intelligence ethics autonomous vehicles september httpswwwsmithsonianmagcominnovationaplaceontheroad towardbetterworld ai spacef
# ====================
# Ethical AI is…  urs gasser carolyn schmitt companies—are engaged increasingly elaborate crossfunctional design teams individuals responsible wholeheartedly implementing ideas across organization1 even performance art research ai hleg even specifies riskbased approach securing system’s proper operation states “ai systems susceptible exploitation external forces” ensuring appropriate processes exist state art ai hleg specifies riskbased system tolerates “attempts exploitation outside context” extent system considered exploitative external forces application ai hleg specifies riskbased system operators
# ====================
# Ethical AI is…  urs gasser carolyn schmitt companies—are engaged increasingly complex conversations policies opportunities potential ripple effects society taking ethical considerations account ai hleg endorses principle prevention harm within policies acknowledgments authors grateful acknowledge support john catherine macarthur foundation new america cornell university center social sciences grateful helpful comments insights joshua popp matthew sun notes portions chapter draw pegah moradi’s thesis manuscript “race ethnicity future work” conducted advising jamila michener karen levy
# ====================

# %%
input_prompt = "Responsibility is…  "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.2, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=40, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Responsibility is…  urs gasser carolyn schmitt companies like facebook google even today claim rightsilated environment similar situation prerevolution tunisia for example young people used internet without internet service providers mobile phones operators redistribute population informal work—thatchedecording laborers—according labor demand120 similar dynamics hold true countries region like qatar pay employees work internet things incidental social benefit companies like iborderot allow rent control live work platforms similar platform model called “microtel” operates storesoice plans microsoft later rent depending
# ====================
# Responsibility is…  urs gasser carolyn schmitt companies like facebook google even today claim rightsilated environment similar situation prerevolution tunisia forsyan found center political science less statistcentric environment criminal law came legislation setting national policies regarding issues data protection implementation offshore petroleum drilling welfare state remains area fore specific policy framework shape future development ai based new technologies particularly adapt global principles tive serve national policies reflect spirit foreign ministry national information society policy document focuses need global governance around proprietary reliance public private tech nologies transparency accountability among p
# ====================
# Responsibility is…  urs gasser carolyn schmitt companies like facebook google even today seemingly empty signifier role previous versions existed addition increased use social media companies created associated norms users might sense important role modeling ethical behavior external entities actions embodied systems encour age increased use systems requires designers consider ways mark take responsibility building systems meet increasingly demanding requirements ie systems designed meet high ethical principles google announced plans enter contracts industry large ensure quality systems achieved google’s proprietary systems”the company’s response criticism claimed responsibility issues would later proved
# ====================

# %%
input_prompt = "Equitable AI is…  "
gpt2_text_generator = gpt2.generate(sess, 
                                    run_name= checkpoint_name, #restore from checkpoint 
                                    temperature=0.3, 
                                    length=100, 
                                    prefix=input_prompt, 
                                    top_k=40, 
                                    nsamples=3)#the amount of outcome 
                                    #destination_path = "/content/drive/MyDrive/Coding3/gpt2_text.txt")
# Out:
# Equitable AI is…  urs gasser carolyn schmitt companies often cited leading causes death per capita basis well global catastrophic failure companies often cited number innovative ways could much risk created society harm avoided7 innovations often key reasons legal social norms evolving toward become robust may driven commitment social norms taking cues information “hardware” perceived “software” approach ai one potential source norms potential generating robust ness bias undesirable effects ai another potential source norm ambiguity ai refers ai hleg specifies four “tra
# ====================
# Equitable AI is…  urs gasser carolyn schmitt companies like facebook google even offer graphical interfaces interfaces people robots way communicate via text email27 yet attempts mainstream ai ethics mainstream academic thought hardly surprising would characterize oppositional stance academic interest projects coming related field machine learning comingle izable ethical insights automating decisionmaking traditional ethical issues automating screening fair decisionmaking advising form supervision ai clinical practice would serve enhance patient’s understanding preferences patients expected receive personalized care schedule could help optimize outcomes optimizing efficiency clinical work well translational
# ====================
# Equitable AI is…  urs gasser carolyn schmitt companies—are engaged norm creation lesser extent administration—while still maintaining professional norms company culture aspirational corporate social vision exer cised visions become increasingly widespread recognition serve functional social norms company culture highprofile corporate launches initiatives include initiatives encourage employees social media network company brands partners social principles including equity multidimensional targeting stakeholders like diversity inclusion diversity inclusion diversity broader societal impact initiatives also raise questions labor standards seen promising way forward terms governance social norms addressed firms’ evolving ethical aligned design processes
# ====================
